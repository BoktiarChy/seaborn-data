# %% [markdown]
# <a href="https://colab.research.google.com/github/BoktiarChy/seaborn-data/blob/master/Lab_2_exploration_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/Pages/DailyHits.csv', index_col=0)

data.index = pd.to_datetime(data.index)

# %%
print(data.head())
print(data.sum())
print(data.describe())
# Out:
#              001  002  003  004  005  006  ...  162  163  164  165  166  167
# Date                                       ...
# 2019-01-01  1062   33   67   42    0    4  ...   10    2    2    2    0    0
# 2019-01-02   976   41   72   19    2    0  ...    0    0    0    0    1    3
# 2019-01-03   956   27   71   28    4    6  ...    6    0    0    3    0    0
# 2019-01-04   976   30   57   29    0    0  ...    0    0    0    0    0    7
# 2019-01-05   956   45   65   27    4    1  ...    0    0    0    0    5    2
#
# [5 rows x 167 columns]
# 001    379682
# 002     17401
# 003     27249
# 004     11668
# 005       533
#         ...
# 163       872
# 164       360
# 165       685
# 166       966
# 167      1196
# Length: 167, dtype: int64
#                001         002         003  ...         165         166         167
# count   365.000000  365.000000  365.000000  ...  365.000000  365.000000  365.000000
# mean   1040.224658   47.673973   74.654795  ...    1.876712    2.646575    3.276712
# std      47.301627   11.961959    9.926447  ...    2.755340    3.806230    4.782366
# min     906.000000   14.000000   47.000000  ...    0.000000    0.000000    0.000000
# 25%    1009.000000   39.000000   67.000000  ...    0.000000    0.000000    0.000000
# 50%    1040.000000   48.000000   75.000000  ...    0.000000    0.000000    0.000000
# 75%    1075.000000   56.000000   81.000000  ...    3.000000    5.000000    6.000000
# max    1159.000000   82.000000  115.000000  ...   14.000000   19.000000   25.000000
#
# [8 rows x 167 columns]

# %%
# sort the data according to the maximum value of each row, smallest first


data = data.reindex(data.sum().sort_values(ascending=False).index, axis=1)
print(data.sum().head(15))



plt.figure(figsize=(8, 8))
x_pos = np.arange(len(data.columns))
plt.bar(x_pos, data.sum(), align='center')
plt.xticks(x_pos, data.columns)
plt.xlabel('Pages', fontsize=18)
plt.ylabel('Hits', fontsize=18)
plt.title('Total pages', fontsize=20)
plt.show()
# Out:
# 015    467123
# 001    379682
# 003     27249
# 080     23357
# 155     22183
# 156     21966
# 048     19229
# 002     17401
# 010     17046
# 004     11668
# 008      1487
# 122      1483
# 092      1450
# 018      1430
# 045      1422
# dtype: int64

# %% [markdown]
# Very insignificant pages have hits ,

# %%
# sort the data according to the maximum value of each row, smallest first

# %%
selected = ['015', '001']
print(data[selected].head())

plt.figure(figsize=(8, 8))
x_pos = np.arange(len(data[selected].columns))
plt.bar(x_pos, data[selected].sum(), align='center')
plt.xticks(x_pos, data[selected].columns)


plt.xlabel('Pages', fontsize=18)
plt.ylabel('Hits', fontsize=18)
plt.title('High Volume pages', fontsize=20)
plt.show()
# Out:
#              015   001
# Date
# 2019-01-01  1184  1062
# 2019-01-02  1266   976
# 2019-01-03  1047   956
# 2019-01-04  1108   976
# 2019-01-05  1214   956

# %%
# data[selected].sum().plot.bar(width=0.8, rot=0, figsize=(8, 8))
selected = ['003', '080', '155', '156','048', '002','010', '004']
print(data[selected].head())

# data[selected].sum().plot.bar(width=0.8, rot=0, figsize=(8, 8))
plt.figure(figsize=(8, 8))
x_pos = np.arange(len(data[selected].columns))
plt.bar(x_pos, data[selected].sum(), align='center')
plt.xticks(x_pos, data[selected].columns)


plt.xlabel('Pages', fontsize=18)
plt.ylabel('Hits', fontsize=18)
plt.title('Medium Volume pages', fontsize=20)
plt.show()
# Out:
#             003  080  155  156  048  002  010  004
# Date
# 2019-01-01   67   67   39   47   37   33   69   42
# 2019-01-02   72   61   59   56   39   41   62   19
# 2019-01-03   71   44   58   46   38   27   64   28
# 2019-01-04   57   61   39   52   35   30   52   29
# 2019-01-05   65   61   40   41   45   45   55   27

# %%
#Question 5

selecetd1 = data.columns[data.sum()< 5000]
print(data[selecetd1].head())


plt.figure(figsize=(8, 8))
x_pos = np.arange(len(data[selected].columns))
plt.bar(x_pos, data[selected].sum(), align='center')
plt.xticks(x_pos, data[selected].columns)


#plt.xlabel('Pages', fontsize=18)
#plt.ylabel('Hits', fontsize=18)
#plt.title('Low Volume pages', fontsize=20)
plt.show()
# Out:
#             008  122  092  018  045  088  ...  138  059  160  079  081  101
# Date                                      ...
# 2019-01-01    0    0    2    6    1    0  ...    2    1    4    1    2    0
# 2019-01-02   14   12    4    0    0    5  ...    1    0    0    2    0    0
# 2019-01-03    0    0    0    2    0    1  ...    0    0    0    3    3    0
# 2019-01-04    0   10    0    5    0    0  ...    0    0    0    0    0    0
# 2019-01-05    0    0   15    0    0    6  ...    0    0    0    3    1    1
#
# [5 rows x 157 columns]

# %%
#Question 6


categories = ['High', 'Medium', 'Low']

categories_selected= [[]for i in range(len(categories))]

for name in data.columns:
  total_sales=data[name].sum()
  if total_sales > 100000:
    category=0
  elif total_sales>40000:
    category=1
  elif total_sales>10000:
    category=2
  else:
    category = 3
  categories_selected[category].append(name)
  print('Product '+ name + ' is '+ categories[category]+ ' volume')

for i in range(len(categories)):
  print(categories[i] + ': '+ str(categories_selected[i]))

for i, selected in enumerate(categories_selected):
  plt.figure(figsize=(8,8))
  x_pos = np.arange(len(data[selected].columns))
  plt.bar(x_pos, data[selected].sum(), align='center')
  plt.xticks(x_pos, data[selected].columns)


  plt.xlabel('Pages', fontsize=18)
  plt.ylabel('Hits', fontsize=18)
  plt.title('Low Volume pages', fontsize=20)
  plt.show()
# Out:
# Product 015 is High volume
# Product 001 is High volume
# Product 003 is Low volume
# Product 080 is Low volume
# Product 155 is Low volume
# Product 156 is Low volume
# Product 048 is Low volume
# Product 002 is Low volume
# Product 010 is Low volume
# Product 004 is Low volume
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-269-93fb95240150> in <module>()
#      16   else:
#      17     category = 3
# ---> 18   categories_selected[category].append(name)
#      19   print('Product '+ name + ' is '+ categories[category]+ ' volume')
#      20
#
# IndexError: list index out of range

# %%
explodeList = []
selected = []
columns = data.columns
data['Others'] = [0] * len(data.index)
for name in columns:
    total_hits = data[name].sum()
    if total_hits > 5000:
        selected.append(name)
        explodeList.append(0)
    else:
        data['Others'] += data[name]
selected.append('Others')
explodeList.append(0.05)
print(data[selected].head())

plt.figure(figsize=(8, 8))
plt.pie(data[selected].sum(), labels=selected, autopct='%1.1f%%', startangle=90, explode=explodeList)
plt.title('Total Page Hits', fontsize=20)
plt.legend(loc=2)
plt.show()
# Out:
#              015   001  003  080  155  156  048  002  010  004  Others
# Date
# 2019-01-01  1184  1062   67   67   39   47   37   33   69   42     358
# 2019-01-02  1266   976   72   61   59   56   39   41   62   19     419
# 2019-01-03  1047   956   71   44   58   46   38   27   64   28     352
# 2019-01-04  1108   976   57   61   39   52   35   30   52   29     291
# 2019-01-05  1214   956   65   61   40   41   45   45   55   27     447
